# %%
# SQL Alchemy
from sqlalchemy import create_engine
import pandas as pd
from Postgres import username, password
import numpy as py
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt

# %%
# Path to sqlite    
from sqlalchemy import create_engine
engine = create_engine(f'postgres://{username}:{password}@localhost:5432/mystery_employee')
connection = engine.connect()

# %%
salaries_df = pd.read_sql("SELECT * FROM salaries",connection)
salaries_df
# Out:
#         emp_no  salary
# 0        10001   60117
# 1        10002   65828
# 2        10003   40006
# 3        10004   40054
# 4        10005   78228
# ...        ...     ...
# 300019  499995   40000
# 300020  499996   58058
# 300021  499997   49597
# 300022  499998   40000
# 300023  499999   63707
#
# [300024 rows x 2 columns]

# %%
salaries_df['salary'].value_counts()
# Out:
# 40000    95346
# 55581       19
# 53738       18
# 53078       18
# 47454       17
#          ...
# 74239        1
# 78148        1
# 76103        1
# 79114        1
# 81762        1
# Name: salary, Length: 50355, dtype: int64

# %%
salaries_df['salary'].describe()
# Out:
# count    300024.000000
# mean      52970.732451
# std       14301.478491
# min       40000.000000
# 25%       40000.000000
# 50%       48681.000000
# 75%       61758.000000
# max      129492.000000
# Name: salary, dtype: float64

# %%
plt.hist(salaries_df.salary)
plt.title ('Salaries by Count')
plt.xlabel ('Salaries')
plt.ylabel ('Frequency')
plt.show
plt.savefig("./EmployeeSQL/employ_salary")

# %%
titles_df = pd.read_sql ("Select * From titles", connection)
titles_df.head()
# Out:
#   title_id               title
# 0    s0001               Staff
# 1    s0002        Senior Staff
# 2    e0001  Assistant Engineer
# 3    e0002            Engineer
# 4    e0003     Senior Engineer

# %%
employees_df =pd.read_sql ("Select * From employees", connection) 
employees_df
# Out:
#         emp_no emp_title_id  birth_date   first_name  last_name sex  \
# 0       473302        s0001  1953-07-25     Hideyuki   Zallocco   M
# 1       475053        e0002  1954-11-18        Byong  Delgrande   F
# 2        57444        e0002  1958-01-30        Berry       Babb   F
# 3       421786        s0001  1957-09-28        Xiong   Verhoeff   M
# 4       282238        e0003  1952-10-28   Abdelkader    Baumann   F
# ...        ...          ...         ...          ...        ...  ..
# 300019  464231        s0001  1958-08-14  Constantino    Eastman   M
# 300020  255832        e0002  1955-05-08       Yuping     Dayang   F
# 300021   76671        s0001  1959-06-09       Ortrud   Plessier   M
# 300022  264920        s0001  1959-09-22        Percy   Samarati   F
# 300023  464503        s0002  1964-05-31       Arvind  Slobodova   M
#
#          hire_date
# 0       1990-04-28
# 1       1991-09-07
# 2       1992-03-21
# 3       1987-11-26
# 4       1991-01-18
# ...            ...
# ...

# %%
d_managers_df = pd.read_sql ("Select * From dept_manager", connection)
d_managers_df
# Out:
#    dept_no  emp_no
# 0     d001  110022
# 1     d001  110039
# 2     d002  110085
# 3     d002  110114
# 4     d003  110183
# 5     d003  110228
# 6     d004  110303
# 7     d004  110344
# 8     d004  110386
# 9     d004  110420
# 10    d005  110511
# 11    d005  110567
# 12    d006  110725
# 13    d006  110765
# 14    d006  110800
# 15    d006  110854
# 16    d007  111035
# 17    d007  111133
# 18    d008  111400
# 19    d008  111534
# 20    d009  111692
# 21    d009  111784
# 22    d009  111877
# 23    d009  111939

# %%
combined_df = pd.merge(salaries_df, employees_df, on="emp_no", how="inner")
combined_df
# Out:
#         emp_no  salary emp_title_id  birth_date first_name last_name sex  \
# 0        10001   60117        e0003  1953-09-02     Georgi   Facello   M
# 1        10002   65828        s0001  1964-06-02    Bezalel    Simmel   F
# 2        10003   40006        e0003  1959-12-03      Parto   Bamford   M
# 3        10004   40054        e0003  1954-05-01  Chirstian   Koblick   M
# 4        10005   78228        s0001  1955-01-21    Kyoichi  Maliniak   M
# ...        ...     ...          ...         ...        ...       ...  ..
# 300019  499995   40000        e0002  1958-09-24     Dekang  Lichtner   F
# 300020  499996   58058        e0003  1953-03-07       Zito      Baaz   M
# 300021  499997   49597        e0003  1961-08-03    Berhard    Lenart   M
# 300022  499998   40000        s0001  1956-09-05   Patricia   Breugel   M
# 300023  499999   63707        e0002  1958-05-01     Sachin   Tsukuda   M
#
#          hire_date
# 0       1986-06-26
# 1       1985-11-21
# 2       1986-08-28
# ...

# %%
combination_df = pd.merge(combined_df, titles_df, on="emp_title_id", how="inner")
combination_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-896434e3ae2f> in <module>()
# ----> 1 combination_df = pd.merge(combined_df, titles_df, on="emp_title_id", how="inner")
#       2 combination_df
#
# C:\Users\kevin\anaconda3\envs\PythonData\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      85         copy=copy,
#      86         indicator=indicator,
# ---> 87         validate=validate,
#      88     )
#      89     return op.get_result()
#
# C:\Users\kevin\anaconda3\envs\PythonData\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     650             self.right_join_keys,
#     651             self.join_names,
# ...
